# %%
import numpy as np 
import pandas as pd
import openturns as ot
import otkerneldesign as otkd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Uncertainty propagation methods
#
# See the following API page regarding the methods used below:
#
# https://openturns.github.io/openturns/latest/user_manual/designs_of_experiments.html
#
# https://efekhari27.github.io/otkerneldesign/master/user_manual/_generated/otkerneldesign.KernelHerding.html

# %%
def generate_MC(distribution, size):
    x_sample = distribution.getSample(size)
    return np.array(x_sample)

def generate_QMC(distribution, size):
    # Other sequences are available (Halton, Faure, etc.)
    # Pass the last argument as True for randomized QMC 
    qmc_experiment = ot.LowDiscrepancyExperiment(ot.SobolSequence(), distribution, size, False) 
    x_sample = qmc_experiment.generate()
    return np.array(x_sample)

def generate_LHS(distribution, size):
    lhs_experiment = ot.LHSExperiment(distribution, size)
    x_sample = lhs_experiment.generate()
    return np.array(x_sample)

def generate_KH(distribution, size):
    # Support points rely on a specific 
    sp = otkd.GreedySupportPoints(
            distribution=distribution,
            candidate_set_size=2 ** 12, # increase if the dimension higher 
            )
    x_sample = sp.select_design(size)
    return np.array(x_sample)

# %% [markdown]
# ## Uniform inputs

# %%
dim = 2
uniform_distribution = ot.ComposedDistribution([ot.Uniform(0., 1.)] * dim)

# %%
size = 128
# Monte Carlo
x_MC_sample = generate_MC(uniform_distribution, size)
# Quasi-Monte Carlo 
x_QMC_sample = generate_QMC(uniform_distribution, size)
# LHS
x_LHS_sample = generate_LHS(uniform_distribution, size)
# Kernel herding 
x_KH_sample = generate_KH(uniform_distribution, size)

# %%
titles_labels = ['Monte Carlo', 'Quasi-Monte Carlo', 'Latin hypercube sampling', 'Kernel herding']
samples_list = [x_MC_sample, x_QMC_sample, x_LHS_sample, x_KH_sample]
fig, axs = plt.subplots(1, 4, figsize=(17, 4))
for i in range(4):
    x_sample = samples_list[i]
    axs[i].scatter(x_sample[:, 0], x_sample[:, 1], marker='.')
    axs[i].set_xlabel('X0')
    axs[i].set_ylabel('X1')
    axs[i].set_title(f'{titles_labels[i]} (n={x_sample.shape[0]})', fontsize=14)

# %% [markdown]
# ### Non-uniform inputs
#
# See the large catalogue of marginals and copulas available in OpenTURNS:
#
# http://openturns.github.io/openturns/latest/user_manual/probabilistic_modelling.html

# %%
weibull = ot.WeibullMin(2.0, 1.5, 1.0)
exponential = ot.Exponential(1.) 
marginals = [weibull, exponential]
# Copulas 
correlation = ot.CorrelationMatrix(2)
correlation[1, 0] = 0.8 # introduce correlation coefficients
normal_copula = ot.NormalCopula(correlation)
# Many other copula models available
clayton_copula = ot.ClaytonCopula(2.5)
# Distributions 
#my_distribution = ot.ComposedDistribution(marginals, clayton_copula)
my_distribution = ot.ComposedDistribution(marginals)

# %%
# 2D joint distributions plotting
graph = my_distribution.drawPDF()
graph.setColors(ot.Drawable.BuildDefaultPalette(10))
graph
# Out:
# class=Graph name=pdf as a function of (X0,X1) implementation=class=GraphImplementation name=pdf as a function of (X0,X1) title=[X0,X1] iso-PDF xTitle=X0 yTitle=X1 axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=pdf as a function of (X0,X1) implementation=class=Contour name=pdf as a function of (X0,X1) x=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=1 data=[[1],[1.04902],[1.09805],[1.14707],[1.1961],[1.24512],[1.29415],[1.34317],[1.3922],[1.44122],[1.49024],[1.53927],[1.58829],[1.63732],[1.68634],[1.73537],[1.78439],[1.83342],[1.88244],[1.93147],[1.98049],[2.02951],[2.07854],[2.12756],[2.17659],[2.22561],[2.27464],[2.32366],[2.37269],[2.42171],[2.47073],[2.51976],[2.56878],[2.61781],[2.66683],[2.71586],[2.76488],[2.81391],[2.86293],[2.91196],[2.96098],[3.01],[3.05903],[3.10805],[3.15708],[3.2061],[3.25513],[3.30415],[3.35318],[3.4022],[3.45122],[3.50025],[3.54927],[3.5983],[3.64732],[3.69635],[3.74537],[3.7944],[3.84342],[3.89245],[3.94147],[3.99049],[4.03952],[4.08854],[4.13757],[4.18659],[4.23562],[4.28464],[4.33367],[4.38269],[4.43171],[4.48074],[4.52976],[4.57879],[4.62781],[4.67684],[4.72586],[4.77489],[4.82391],[4.87294],[4.92196],[4.97098],[5.02001],[5.06903],[5.11806],[5.16708],[5.21611],[5.26513],[5.31416],[5.36318],[5.4122],[5.46123],[5.51025],[5.55928],[5.6083],[5.65733],[5.70635],[5.75538],[5.8044],[5.85343],[5.90245],[5.95147],[6.0005],[6.04952],[6.09855],[6.14757],[6.1966],[6.24562],[6.29465],[6.34367],[6.39269],[6.44172],[6.49074],[6.53977],[6.58879],[6.63782],[6.68684],[6.73587],[6.78489],[6.83392],[6.88294],[6.93196],[6.98099],[7.03001],[7.07904],[7.12806],[7.17709],[7.22611],[7.27514]] y=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=1 data=[[0],[0.0324383],[0.0648766],[0.0973149],[0.129753],[0.162191],[0.19463],[0.227068],[0.259506],[0.291945],[0.324383],[0.356821],[0.38926],[0.421698],[0.454136],[0.486574],[0.519013],[0.551451],[0.583889],[0.616328],[0.648766],[0.681204],[0.713642],[0.746081],[0.778519],[0.810957],[0.843396],[0.875834],[0.908272],[0.94071],[0.973149],[1.00559],[1.03803],[1.07046],[1.1029],[1.13534],[1.16778],[1.20022],[1.23266],[1.26509],[1.29753],[1.32997],[1.36241],[1.39485],[1.42728],[1.45972],[1.49216],[1.5246],[1.55704],[1.58948],[1.62191],[1.65435],[1.68679],[1.71923],[1.75167],[1.78411],[1.81654],[1.84898],[1.88142],[1.91386],[1.9463],[1.97874],[2.01117],[2.04361],[2.07605],[2.10849],[2.14093],[2.17337],[2.2058],[2.23824],[2.27068],[2.30312],[2.33556],[2.368],[2.40043],[2.43287],[2.46531],[2.49775],[2.53019],[2.56263],[2.59506],[2.6275],[2.65994],[2.69238],[2.72482],[2.75725],[2.78969],[2.82213],[2.85457],[2.88701],[2.91945],[2.95188],[2.98432],[3.01676],[3.0492],[3.08164],[3.11408],[3.14651],[3.17895],[3.21139],[3.24383],[3.27627],[3.30871],[3.34114],[3.37358],[3.40602],[3.43846],[3.4709],[3.50334],[3.53577],[3.56821],[3.60065],[3.63309],[3.66553],[3.69797],[3.7304],[3.76284],[3.79528],[3.82772],[3.86016],[3.8926],[3.92503],[3.95747],[3.98991],[4.02235],[4.05479],[4.08722],[4.11966],[4.1521]] levels=class=Point name=Unnamed dimension=1 values=[0.000394963] labels=[0.000394963] show labels=false derived from class=DrawableImplementation name=pdf as a function of (X0,X1) legend=0.000394963 data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=16641 dimension=1 data=[[0],[0.116973],[0.164268],...,[9.10759e-05],[8.5704e-05],[8.06259e-05]] color=#1f77b4 fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1,class=Drawable name=pdf as a function of (X0,X1) implementation=class=Contour name=pdf as a function of (X0,X1) x=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=1 data=[[1],[1.04902],[1.09805],[1.14707],[1.1961],[1.24512],[1.29415],[1.34317],[1.3922],[1.44122],[1.49024],[1.53927],[1.58829],[1.63732],[1.68634],[1.73537],[1.78439],[1.83342],[1.88244] ...

# %%
size = 256
# Monte Carlo
x_MC_sample = generate_MC(my_distribution, size)
# Quasi-Monte Carlo 
x_QMC_sample = generate_QMC(my_distribution, size)
# LHS
# Note that the LHSExperiment class only accept independent distributions to keep the LHS structure
x_LHS_sample = generate_LHS(my_distribution, size)
# Kernel herding 
x_KH_sample = generate_KH(my_distribution, size)

# %%
plotted_size = 128
samples_list = [x_MC_sample[:plotted_size, :], x_QMC_sample[:plotted_size, :], x_LHS_sample[:plotted_size, :], x_KH_sample[:plotted_size, :]]
fig, axs = plt.subplots(1, 4, figsize=(17, 4))
for i in range(4):
    x_sample = samples_list[i]
    axs[i].scatter(x_sample[:, 0], x_sample[:, 1], marker='.')
    axs[i].set_xlabel('X0')
    axs[i].set_ylabel('X1')
    axs[i].set_title(f'{titles_labels[i]} (n={x_sample.shape[0]})', fontsize=14)
    axs[i].set_xlim(0, 7)
    axs[i].set_ylim(0, 7)

# %% [markdown]
# ## Mean estimation
#
# Function in OpenTURNS can be defined either using `ot.SymbolicFunction` when the function is explicit, otherwise it can be done using `ot.PythonFunction`

# %%
my_function = ot.SymbolicFunction(['x1', 'x2'], ['x1^2 + 3*x2'])

# %% [markdown]
# ### Monte Carlo reference

# %%
ref_size = int(1e6)
x_MC_reference = my_distribution.getSample(ref_size)
y_MC_reference = my_function(x_MC_reference)
mc_ref = np.mean(y_MC_reference)
print(f'Monte Carlo mean reference: {mc_ref}')
# Out:
# Monte Carlo mean reference: 12.366161223129236

# %% [markdown]
# ### Mean convergence benchmark

# %%
x_indexes = np.arange(1, size + 1)
# Evaluate designs
y_MC_sample = my_function(x_MC_sample)
y_QMC_sample = my_function(x_QMC_sample)
y_LHS_sample = my_function(x_LHS_sample)
y_KH_sample = my_function(x_KH_sample)
# Estimate means
y_MC_means = np.cumsum(y_MC_sample) / x_indexes
y_QMC_means = np.cumsum(y_QMC_sample) / x_indexes
y_LHS_means = np.cumsum(y_LHS_sample) / x_indexes
y_KH_means = np.cumsum(y_KH_sample) / x_indexes

# %%
titles_labels = ['Monte Carlo', 'Quasi-Monte Carlo', 'Latin hypercube sampling', 'Kernel herding']
mean_convergence_list = [y_MC_means, y_QMC_means, y_LHS_means, y_KH_means]
fig = plt.figure()
for i, mean_convergence in enumerate(mean_convergence_list): 
    plt.plot(x_indexes, mean_convergence, color=f'C{i}', label=titles_labels[i])
plt.axhline(mc_ref, color='k', label="MC reference")
plt.xlabel('Sample size')
plt.ylabel('Mean convergence')
plt.legend(loc='lower right');

# %% [markdown]
# ## High-dimension sub-projection

# %%
dim = 2
n = 1024
# Quasi-Monte Carlo 
x_MC_sample = generate_MC(ot.ComposedDistribution([ot.Uniform(0., 1.)] * dim), n)
# Regular grid
levels = int(n ** (1/dim))
mesher = ot.IntervalMesher([levels-1] * dim)
interval = ot.Interval([0.] * dim, [1.] * dim)
mesh = mesher.build(interval)
regular_grid_sample = np.array(mesh.getVertices())

# %%
samples_list = [x_MC_sample, regular_grid_sample]
titles_labels = ['Monte Carlo', 'Regular grid']
fig, axs = plt.subplots(1, 2, figsize=(9, 4))
for i in range(2):
    x_sample = samples_list[i]
    axs[i].scatter(x_sample[:, 0], x_sample[:, 1], marker='.')
    axs[i].set_xlabel('X0')
    axs[i].set_ylabel('X1')
    axs[i].set_title(f'{titles_labels[i]} (d={x_sample.shape[1]}, n={x_sample.shape[0]})', fontsize=14)
    axs[i].set_xlim(-0.1, 1.1)
    axs[i].set_ylim(-0.1, 1.1)
fig.savefig("figures/MCvsREGULAR_D2.jpg", dpi=300, transparent=True)

# %%
dim = 5
n = 1024
# Quasi-Monte Carlo 
x_MC_sample = generate_MC(ot.ComposedDistribution([ot.Uniform(0., 1.)] * dim), n)
# Regular grid
levels = int(n ** (1/dim))
mesher = ot.IntervalMesher([levels-1] * dim)
interval = ot.Interval([0.] * dim, [1.] * dim)
mesh = mesher.build(interval)
regular_grid_sample = np.array(mesh.getVertices())

# %%
samples_list = [x_MC_sample, regular_grid_sample]
titles_labels = ['Monte Carlo', 'Regular grid']
fig, axs = plt.subplots(1, 2, figsize=(9, 4))
for i in range(2):
    x_sample = samples_list[i]
    axs[i].scatter(x_sample[:, 0], x_sample[:, 1], marker='.')
    axs[i].set_xlabel('X0')
    axs[i].set_ylabel('X1')
    axs[i].set_title(f'{titles_labels[i]} (d={x_sample.shape[1]}, n={x_sample.shape[0]})', fontsize=14)
    axs[i].set_xlim(-0.1, 1.1)
    axs[i].set_ylim(-0.1, 1.1)
fig.savefig("figures/MCvsREGULAR_D5.jpg", dpi=300, transparent=True)
